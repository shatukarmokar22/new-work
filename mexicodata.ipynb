# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read CSV File

# %%
df= pd.read_csv("mexico_covid19.csv")
df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0           0                25           Sinaloa      SL  ...        2
# 1           0                14           Jalisco      JC  ...        2
# 2           0                 8         Chihuahua      CH  ...        2
# 3           0                 9  Ciudad de Mexico      DF  ...        2
# 4           0                 9  Ciudad de Mexico      DF  ...        2
# ...       ...               ...               ...     ...  ...      ...
# 263002      0                32         Zacatecas      ZS  ...        2
# 263003      0                12          Guerrero      GR  ...        2
# 263004      0                20            Oaxaca      OC  ...        2
# 263005      0                13           Hidalgo      HG  ...        2
# 263006      0                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %% [markdown]
# # Column Renaming

# %%
df.rename(columns = {'id':'ID', 'FECHA_ARCHIVO':'Data_Archieve','ID_REGISTRO':'Registration_ID','ENTIDAD_UM':'ENTITY','ENTIDAD_RES':'ENTITY_RESULT','RESULTADO':'OUTCOMES','ENTIDAD_REGISTRO':'REGISTRATION_ENTITY','ENTIDAD':'ENTITY','ABR_ENT':'APR_ENTITY','FECHA_ACTUALIZATION':'DATE_UPDATE',
                      'ORIGEN':'SOURCE', 'SECTOR':'SECTOR', 'SEXO':'SEX','ENTIDAD_NAC':'NAC_ENTITY','MUNICIPIO_RES':'MUNICIPALITY_RESULT','TIPO_PACIENTE':'PATIENT_TYPE','FECHA_INGRRSO':'ADMISSION_DATE','FECHA_SINTOMAS':'DATE_SYMPTOMS','FECHA_DEF':'DATE_DEF','INTUBADO':'INTUBATED','NEUMONIA':'PNEUMONIA','EDAD':'AGE','NACIONALIDAD':'NATIONALITY',
                    'EMBARAZO':'PREGNANCY','HABLA_LENGUA_INDIG':'SPEAK_LINGUA_INDIG','EPOC':'COPD','ASMA':'ASTHMA','OTRA_COM':'ANOTHER_COM','OBESIDAD':'OBESITY','RENAL_CRONICA':'KIDNEY_CHRONICLE','TABAQUISMO':'SMOKING','OTRO_CASO':'ANOTHER_CASE','MIGRANTE':'MIgrant','PAIS_NACIONALIDAD':'COUNTRY_NATIONALITY','PAIS_ORIGEN':'COUNTRY_ORIGIN','UCI':'ICU'},inplace=True
                    )

# %%
df
# Out:
#              ID Data_Archieve Registration_ID ENTITY  ENTITY_RESULT  OUTCOMES  \
# 0          9269    2020-04-12          00011f     25             25         2
# 1         33333    2020-04-12          00014e     14             14         2
# 2         35483    2020-04-12          000153      8              8         1
# 3          7062    2020-04-12          0001b6      9             15         1
# 4         23745    2020-04-12          0001c1      9              9         2
# ...         ...           ...             ...    ...            ...       ...
# 263002  7094887    2020-06-03          1e019c     32             32         1
# 263003  7053721    2020-06-03          1e2b05     12             12         1
# 263004  7055429    2020-06-03          1e473f     20             20         1
# 263005  7043768    2020-06-03          1e6da1     13             13         1
# 263006  7093277    2020-06-03          1e8453      9              9         1
#
#         DELAY  REGISTRATION_ENTITY            ENTITY APR_ENTITY  ...  \
# 0           0                   25           Sinaloa         SL  ...
# 1           0                   14           Jalisco         JC  ...
# 2           0                    8         Chihuahua         CH  ...
# 3           0                    9  Ciudad de Mexico         DF  ...
# 4           0                    9  Ciudad de Mexico         DF  ...
# ...       ...                  ...               ...        ...  ...
# 263002      0                   32         Zacatecas         ZS  ...
# 263003      0                   12          Guerrero         GR  ...
# 263004      0                   20            Oaxaca         OC  ...
# 263005      0                   13           Hidalgo         HG  ...
# 263006      0                    9  Ciudad de Mexico         DF  ...
#
#        ANOTHER_COM  CARDIOVASCULAR  OBESITY  KIDNEY_CHRONICLE  SMOKING  \
# 0                2               2        1                 2        2
# 1                2               2        1                 2        1
# 2                2               2        2                 2        2
# 3                2               2        1                 2        2
# 4                2               2        2                 2        2
# ...            ...             ...      ...               ...      ...
# 263002           2               2        2                 2        2
# 263003           2               2        1                 2        2
# 263004           2               2        2                 1        2
# 263005           2               2        2                 2        2
# 263006           2               2        2                 2        2
#
#         ANOTHER_CASE  MIgrant COUNTRY_NATIONALITY COUNTRY_ORIGIN ICU
# 0                  2       99             M̩xico             97  97
# 1                 99       99             M̩xico             97   2
# 2                 99       99             M̩xico             97   2
# 3                 99       99             M̩xico             97  97
# 4                 99       99             M̩xico             97  97
# ...              ...      ...                 ...            ...  ..
# 263002             1       99             M̩xico             99  97
# 263003            99       99             M̩xico             99   2
# 263004            99       99             M̩xico             99   2
# 263005             2       99             M̩xico             99   2
# 263006             2       99             M̩xico             99  97
#
# [263007 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['id', 'FECHA_ARCHIVO', 'ID_REGISTRO', 'ENTIDAD_UM', 'ENTIDAD_RES',
#        'RESULTADO', 'DELAY', 'ENTIDAD_REGISTRO', 'ENTIDAD', 'ABR_ENT',
#        'FECHA_ACTUALIZACION', 'ORIGEN', 'SECTOR', 'SEXO', 'ENTIDAD_NAC',
#        'MUNICIPIO_RES', 'TIPO_PACIENTE', 'FECHA_INGRESO', 'FECHA_SINTOMAS',
#        'FECHA_DEF', 'INTUBADO', 'NEUMONIA', 'EDAD', 'NACIONALIDAD', 'EMBARAZO',
#        'HABLA_LENGUA_INDIG', 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR',
#        'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR', 'OBESIDAD',
#        'RENAL_CRONICA', 'TABAQUISMO', 'OTRO_CASO', 'MIGRANTE',
#        'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
df[2:5]
# Out:
#       id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  \
# 2  35483    2020-04-12      000153           8            8          1    NaN
# 3   7062    2020-04-12      0001b6           9           15          1    NaN
# 4  23745    2020-04-12      0001c1           9            9          2    NaN
#
#    ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  CARDIOVASCULAR  \
# 2                 8         Chihuahua      CH  ...        2               2
# 3                 9  Ciudad de Mexico      DF  ...        2               2
# 4                 9  Ciudad de Mexico      DF  ...        2               2
#
#    OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  MIGRANTE PAIS_NACIONALIDAD  \
# 2         2              2           2         99        99           M̩xico
# 3         1              2           2         99        99           M̩xico
# 4         2              2           2         99        99           M̩xico
#
#   PAIS_ORIGEN UCI
# 2          97   2
# 3          97  97
# 4          97  97
#
# [3 rows x 41 columns]

# %% [markdown]
# ### PRINT A COLUMN

# %%
df.ENTIDAD
# Out:
# 0                  Sinaloa
# 1                  Jalisco
# 2                Chihuahua
# 3         Ciudad de Mexico
# 4         Ciudad de Mexico
#                 ...
# 263002           Zacatecas
# 263003            Guerrero
# 263004              Oaxaca
# 263005             Hidalgo
# 263006    Ciudad de Mexico
# Name: ENTIDAD, Length: 263007, dtype: object

# %% [markdown]
# #### INSERT FIRST ROW

# %%
df.tail(1)
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 263006    NaN                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 263006        99           M̩xico          99  97
#
# [1 rows x 41 columns]

# %% [markdown]
# ### show only three columns

# %%
df[['id','FECHA_ARCHIVO','RENAL_CRONICA']]
# Out:
#              id FECHA_ARCHIVO  RENAL_CRONICA
# 0          9269    2020-04-12              2
# 1         33333    2020-04-12              2
# 2         35483    2020-04-12              2
# 3          7062    2020-04-12              2
# 4         23745    2020-04-12              2
# ...         ...           ...            ...
# 263002  7094887    2020-06-03              2
# 263003  7053721    2020-06-03              2
# 263004  7055429    2020-06-03              1
# 263005  7043768    2020-06-03              2
# 263006  7093277    2020-06-03              2
#
# [263007 rows x 3 columns]

# %% [markdown]
# ## Count NAN VALUE IN THE DATAFRAME

# %%
df.isna().sum()
# Out:
# ID                     0
# Data_Archieve          0
# Registration_ID        0
# ENTIDAD_UM             0
# ENTITY_RESULT          0
# OUTCOMES               0
# DELAY                  0
# REGISTRATION_ENTITY    0
# ENTITY                 0
# APR_ENTITY             0
# FECHA_ACTUALIZACION    0
# SOURCE                 0
# SECTOR                 0
# SEX                    0
# NAC_ENTITY             0
# MUNICIPALITY_RESULT    6
# PATIENT_TYPE           0
# FECHA_INGRESO          0
# DATE_SYMPTOMS          0
# DATE_DEF               0
# INTUBATED              0
# PNEUMONIA              0
# AGE                    0
# NATIONALITY            0
# PREGNANCY              0
# SPEAK_LINGUA_INDIG     0
# DIABETES               0
# COPD                   0
# ASTHMA                 0
# INMUSUPR               0
# HIPERTENSION           0
# ANOTHER_COM            0
# CARDIOVASCULAR         0
# OBESITY                0
# KIDNEY_CHRONICLE       0
# SMOKING                0
# ANOTHER_CASE           0
# MIgrant                0
# COUNTRY_NATIONALITY    0
# COUNTRY_ORIGIN         0
# ICU                    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 6

# %%
df = pd.DataFrame(df)
df
# Out:
#              ID Data_Archieve Registration_ID  ENTIDAD_UM  ENTITY_RESULT  \
# 0          9269    2020-04-12          00011f          25             25
# 1         33333    2020-04-12          00014e          14             14
# 2         35483    2020-04-12          000153           8              8
# 3          7062    2020-04-12          0001b6           9             15
# 4         23745    2020-04-12          0001c1           9              9
# ...         ...           ...             ...         ...            ...
# 263002  7094887    2020-06-03          1e019c          32             32
# 263003  7053721    2020-06-03          1e2b05          12             12
# 263004  7055429    2020-06-03          1e473f          20             20
# 263005  7043768    2020-06-03          1e6da1          13             13
# 263006  7093277    2020-06-03          1e8453           9              9
#
#         OUTCOMES  DELAY  REGISTRATION_ENTITY            ENTITY APR_ENTITY  \
# 0              2      0                   25           Sinaloa         SL
# 1              2      0                   14           Jalisco         JC
# 2              1      0                    8         Chihuahua         CH
# 3              1      0                    9  Ciudad de Mexico         DF
# 4              2      0                    9  Ciudad de Mexico         DF
# ...          ...    ...                  ...               ...        ...
# 263002         1      0                   32         Zacatecas         ZS
# 263003         1      0                   12          Guerrero         GR
# 263004         1      0                   20            Oaxaca         OC
# 263005         1      0                   13           Hidalgo         HG
# 263006         1      0                    9  Ciudad de Mexico         DF
#
#         ... ANOTHER_COM  CARDIOVASCULAR  OBESITY  KIDNEY_CHRONICLE  SMOKING  \
# 0       ...           2               2        1                 2        2
# 1       ...           2               2        1                 2        1
# 2       ...           2               2        2                 2        2
# 3       ...           2               2        1                 2        2
# 4       ...           2               2        2                 2        2
# ...     ...         ...             ...      ...               ...      ...
# 263002  ...           2               2        2                 2        2
# 263003  ...           2               2        1                 2        2
# 263004  ...           2               2        2                 1        2
# 263005  ...           2               2        2                 2        2
# 263006  ...           2               2        2                 2        2
#
#         ANOTHER_CASE  MIgrant COUNTRY_NATIONALITY COUNTRY_ORIGIN ICU
# 0                  2       99             M̩xico             97  97
# 1                 99       99             M̩xico             97   2
# 2                 99       99             M̩xico             97   2
# 3                 99       99             M̩xico             97  97
# 4                 99       99             M̩xico             97  97
# ...              ...      ...                 ...            ...  ..
# 263002             1       99             M̩xico             99  97
# 263003            99       99             M̩xico             99   2
# 263004            99       99             M̩xico             99   2
# 263005             2       99             M̩xico             99   2
# 263006             2       99             M̩xico             99  97
#
# [263007 rows x 41 columns]

# %% [markdown]
# ## SUPPLY DICTIONARY FOR SET INDEX

# %%
import pandas as pd
df = pd.read_csv("mexico_covid19.csv",na_values={
    
    'DELAY' : ["not available","n.a.",0]
})
df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0         NaN                25           Sinaloa      SL  ...        2
# 1         NaN                14           Jalisco      JC  ...        2
# 2         NaN                 8         Chihuahua      CH  ...        2
# 3         NaN                 9  Ciudad de Mexico      DF  ...        2
# 4         NaN                 9  Ciudad de Mexico      DF  ...        2
# ...       ...               ...               ...     ...  ...      ...
# 263002    NaN                32         Zacatecas      ZS  ...        2
# 263003    NaN                12          Guerrero      GR  ...        2
# 263004    NaN                20            Oaxaca      OC  ...        2
# 263005    NaN                13           Hidalgo      HG  ...        2
# 263006    NaN                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %% [markdown]
# ## Maximum value of tabaquismo

# %%
df['TABAQUISMO'].max()
# Out:
# 98

# %% [markdown]
# ## Limitation for entidad_um column

# %%
df[df.ENTIDAD_UM>=32]
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 28         5687    2020-04-12      000947          32           32          2
# 44        35105    2020-04-12      000da7          32           32          2
# 64        35422    2020-04-12      0013da          32           32          2
# 197        9169    2020-04-12      003e61          32           32          2
# 226       28522    2020-04-12      0045d2          32           32          2
# ...         ...           ...         ...         ...          ...        ...
# 262067  7097991    2020-06-03      1727f0          32           32          1
# 262374  7047135    2020-06-03      1c09fc          32           32          1
# 262625  7216684    2020-06-03      061f24          32           32          2
# 262822  7233988    2020-06-03      11fb26          32           32          2
# 263002  7094887    2020-06-03      1e019c          32           32          1
#
#         DELAY  ENTIDAD_REGISTRO    ENTIDAD ABR_ENT  ... OTRA_COM  \
# 28        NaN                32  Zacatecas      ZS  ...        1
# 44        NaN                32  Zacatecas      ZS  ...        2
# 64        NaN                32  Zacatecas      ZS  ...        2
# 197       NaN                32  Zacatecas      ZS  ...        2
# 226       NaN                32  Zacatecas      ZS  ...        2
# ...       ...               ...        ...     ...  ...      ...
# 262067    NaN                32  Zacatecas      ZS  ...        2
# 262374    NaN                32  Zacatecas      ZS  ...        2
# 262625    NaN                32  Zacatecas      ZS  ...        2
# 262822    NaN                32  Zacatecas      ZS  ...        2
# 263002    NaN                32  Zacatecas      ZS  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 28                   2         2              2           2          1
# 44                   2         2              2           2          2
# 64                   2         2              2           2          1
# 197                  1         2              2           2         99
# 226                  2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 262067               2         2              2           2          2
# 262374               2         1              2           2          2
# 262625               2         2              2           2          2
# 262822               2         2              2           2          1
# 263002               2         2              2           2          1
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 28            99           M̩xico          97  97
# 44            99                99          97  97
# 64            99           M̩xico          97  97
# 197           99           M̩xico          97  97
# 226           99           M̩xico          97   2
# ...          ...               ...         ...  ..
# 262067        99           M̩xico          99  97
# 262374        99           M̩xico          99   2
# 262625        99           M̩xico          99  97
# 262822        99           M̩xico          99  97
# 263002        99           M̩xico          99  97
#
# [1617 rows x 41 columns]

# %%
df['EDAD'].std()
# Out:
# 16.903824487378323

# %% [markdown]
# ## MAXIMUM AGED PEOPLE DATA

# %%
df[df.EDAD == df['EDAD'].max()]
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 59344    752892    2020-04-26      032079          19           19          2
# 136001  2843376    2020-05-15      09ffba           1            1          2
# 214920  5146709    2020-05-27      17422d          20           20          1
#
#         DELAY  ENTIDAD_REGISTRO         ENTIDAD ABR_ENT  ... OTRA_COM  \
# 59344     NaN                19      Nuevo Leon      NL  ...        2
# 136001    NaN                 1  Aguascalientes      AS  ...        2
# 214920    NaN                20          Oaxaca      OC  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 59344                2         2              2           2          2
# 136001               2         2              2           2          1
# 214920               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 59344         99           M̩xico          99  97
# 136001        99           M̩xico          99  97
# 214920        99           M̩xico          99  97
#
# [3 rows x 41 columns]

# %%
new_df = df.replace({
    0:np.NAN
})
new_df
# Out:
#                id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  \
# 0          9269.0    2020-04-12      00011f        25.0         25.0
# 1         33333.0    2020-04-12      00014e        14.0         14.0
# 2         35483.0    2020-04-12      000153         8.0          8.0
# 3          7062.0    2020-04-12      0001b6         9.0         15.0
# 4         23745.0    2020-04-12      0001c1         9.0          9.0
# ...           ...           ...         ...         ...          ...
# 263002  7094887.0    2020-06-03      1e019c        32.0         32.0
# 263003  7053721.0    2020-06-03      1e2b05        12.0         12.0
# 263004  7055429.0    2020-06-03      1e473f        20.0         20.0
# 263005  7043768.0    2020-06-03      1e6da1        13.0         13.0
# 263006  7093277.0    2020-06-03      1e8453         9.0          9.0
#
#         RESULTADO  DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ...  \
# 0             2.0    NaN              25.0           Sinaloa      SL  ...
# 1             2.0    NaN              14.0           Jalisco      JC  ...
# 2             1.0    NaN               8.0         Chihuahua      CH  ...
# 3             1.0    NaN               9.0  Ciudad de Mexico      DF  ...
# 4             2.0    NaN               9.0  Ciudad de Mexico      DF  ...
# ...           ...    ...               ...               ...     ...  ...
# 263002        1.0    NaN              32.0         Zacatecas      ZS  ...
# 263003        1.0    NaN              12.0          Guerrero      GR  ...
# 263004        1.0    NaN              20.0            Oaxaca      OC  ...
# 263005        1.0    NaN              13.0           Hidalgo      HG  ...
# 263006        1.0    NaN               9.0  Ciudad de Mexico      DF  ...
#
#        OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  \
# 0           2.0             2.0       1.0            2.0         2.0
# 1           2.0             2.0       1.0            2.0         1.0
# 2           2.0             2.0       2.0            2.0         2.0
# 3           2.0             2.0       1.0            2.0         2.0
# 4           2.0             2.0       2.0            2.0         2.0
# ...         ...             ...       ...            ...         ...
# 263002      2.0             2.0       2.0            2.0         2.0
# 263003      2.0             2.0       1.0            2.0         2.0
# 263004      2.0             2.0       2.0            1.0         2.0
# 263005      2.0             2.0       2.0            2.0         2.0
# 263006      2.0             2.0       2.0            2.0         2.0
#
#         OTRO_CASO  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN   UCI
# 0             2.0      99.0           M̩xico          97  97.0
# 1            99.0      99.0           M̩xico          97   2.0
# 2            99.0      99.0           M̩xico          97   2.0
# 3            99.0      99.0           M̩xico          97  97.0
# 4            99.0      99.0           M̩xico          97  97.0
# ...           ...       ...               ...         ...   ...
# 263002        1.0      99.0           M̩xico          99  97.0
# 263003       99.0      99.0           M̩xico          99   2.0
# 263004       99.0      99.0           M̩xico          99   2.0
# 263005        2.0      99.0           M̩xico          99   2.0
# 263006        2.0      99.0           M̩xico          99  97.0
#
# [263007 rows x 41 columns]

# %% [markdown]
# ## replace column data of ENTIDAD

# %%
new_df = df.replace(['Sinaloa','Jalisco','Chihuahua','Ciudad de Mexico'],[1,2,3,4])
new_df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO    ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0         NaN                25          1      SL  ...        2
# 1         NaN                14          2      JC  ...        2
# 2         NaN                 8          3      CH  ...        2
# 3         NaN                 9          4      DF  ...        2
# 4         NaN                 9          4      DF  ...        2
# ...       ...               ...        ...     ...  ...      ...
# 263002    NaN                32  Zacatecas      ZS  ...        2
# 263003    NaN                12   Guerrero      GR  ...        2
# 263004    NaN                20     Oaxaca      OC  ...        2
# 263005    NaN                13    Hidalgo      HG  ...        2
# 263006    NaN                 9          4      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %%
df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0         NaN                25           Sinaloa      SL  ...        2
# 1         NaN                14           Jalisco      JC  ...        2
# 2         NaN                 8         Chihuahua      CH  ...        2
# 3         NaN                 9  Ciudad de Mexico      DF  ...        2
# 4         NaN                 9  Ciudad de Mexico      DF  ...        2
# ...       ...               ...               ...     ...  ...      ...
# 263002    NaN                32         Zacatecas      ZS  ...        2
# 263003    NaN                12          Guerrero      GR  ...        2
# 263004    NaN                20            Oaxaca      OC  ...        2
# 263005    NaN                13           Hidalgo      HG  ...        2
# 263006    NaN                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %%
new_df = df.fillna(0)
new_df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0         0.0                25           Sinaloa      SL  ...        2
# 1         0.0                14           Jalisco      JC  ...        2
# 2         0.0                 8         Chihuahua      CH  ...        2
# 3         0.0                 9  Ciudad de Mexico      DF  ...        2
# 4         0.0                 9  Ciudad de Mexico      DF  ...        2
# ...       ...               ...               ...     ...  ...      ...
# 263002    0.0                32         Zacatecas      ZS  ...        2
# 263003    0.0                12          Guerrero      GR  ...        2
# 263004    0.0                20            Oaxaca      OC  ...        2
# 263005    0.0                13           Hidalgo      HG  ...        2
# 263006    0.0                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0         NaN                25           Sinaloa      SL  ...        2
# 1         NaN                14           Jalisco      JC  ...        2
# 2         NaN                 8         Chihuahua      CH  ...        2
# 3         NaN                 9  Ciudad de Mexico      DF  ...        2
# 4         NaN                 9  Ciudad de Mexico      DF  ...        2
# ...       ...               ...               ...     ...  ...      ...
# 263002    NaN                32         Zacatecas      ZS  ...        2
# 263003    NaN                12          Guerrero      GR  ...        2
# 263004    NaN                20            Oaxaca      OC  ...        2
# 263005    NaN                13           Hidalgo      HG  ...        2
# 263006    NaN                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %%
df.describe()
# Out:
#                  id     ENTIDAD_UM    ENTIDAD_RES      RESULTADO  DELAY  \
# count  2.630070e+05  263007.000000  263007.000000  263007.000000    0.0
# mean   2.946176e+06      14.844601      15.127719       1.609672    NaN
# std    2.212368e+06       8.001043       7.904314       0.487825    NaN
# min    1.000000e+00       1.000000       1.000000       1.000000    NaN
# 25%    8.689635e+05       9.000000       9.000000       1.000000    NaN
# 50%    2.733242e+06      14.000000      15.000000       2.000000    NaN
# 75%    4.789668e+06      21.000000      21.000000       2.000000    NaN
# max    7.277125e+06      32.000000      32.000000       2.000000    NaN
#
#        ENTIDAD_REGISTRO         ORIGEN         SECTOR           SEXO  \
# count     263007.000000  263007.000000  263007.000000  263007.000000
# mean          15.092271       1.635789       9.601680       1.510682
# std            7.915406       0.481209       7.265468       0.499887
# min            1.000000       1.000000       1.000000       1.000000
# 25%            9.000000       1.000000       4.000000       1.000000
# 50%           15.000000       2.000000      12.000000       2.000000
# 75%           21.000000       2.000000      12.000000       2.000000
# max           32.000000       2.000000      99.000000       2.000000
#
#          ENTIDAD_NAC  ...       INMUSUPR   HIPERTENSION       OTRA_COM  \
# count  263007.000000  ...  263007.000000  263007.000000  263007.000000
# mean       19.691004  ...       2.359667       2.174185       2.453961
# std        19.378113  ...       6.021830       5.745114       6.850231
# min         1.000000  ...       1.000000       1.000000       1.000000
# 25%         9.000000  ...       2.000000       2.000000       2.000000
# 50%        15.000000  ...       2.000000       2.000000       2.000000
# 75%        24.000000  ...       2.000000       2.000000       2.000000
# max        99.000000  ...      98.000000      98.000000      98.000000
#
#        CARDIOVASCULAR       OBESIDAD  RENAL_CRONICA     TABAQUISMO  \
# count   263007.000000  263007.000000  263007.000000  263007.000000
# mean         2.324980       2.184763       2.320231       2.268217
# std          5.796086       5.817362       5.722995       5.867586
# min          1.000000       1.000000       1.000000       1.000000
# 25%          2.000000       2.000000       2.000000       2.000000
# 50%          2.000000       2.000000       2.000000       2.000000
# 75%          2.000000       2.000000       2.000000       2.000000
# max         98.000000      98.000000      98.000000      98.000000
#
#            OTRO_CASO       MIGRANTE            UCI
# count  263007.000000  263007.000000  263007.000000
# mean       32.283764      98.593680      74.541012
# std        45.350310       6.275497      40.384991
# min         1.000000       1.000000       1.000000
# 25%         1.000000      99.000000      97.000000
# 50%         2.000000      99.000000      97.000000
# 75%        99.000000      99.000000      97.000000
# max        99.000000      99.000000      99.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Drop multiple specific column

# %%
df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
#         DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 0         NaN                25           Sinaloa      SL  ...        2
# 1         NaN                14           Jalisco      JC  ...        2
# 2         NaN                 8         Chihuahua      CH  ...        2
# 3         NaN                 9  Ciudad de Mexico      DF  ...        2
# 4         NaN                 9  Ciudad de Mexico      DF  ...        2
# ...       ...               ...               ...     ...  ...      ...
# 263002    NaN                32         Zacatecas      ZS  ...        2
# 263003    NaN                12          Guerrero      GR  ...        2
# 263004    NaN                20            Oaxaca      OC  ...        2
# 263005    NaN                13           Hidalgo      HG  ...        2
# 263006    NaN                 9  Ciudad de Mexico      DF  ...        2
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                    2         1              2           2          2
# 1                    2         1              2           1         99
# 2                    2         2              2           2         99
# 3                    2         1              2           2         99
# 4                    2         2              2           2         99
# ...                ...       ...            ...         ...        ...
# 263002               2         2              2           2          1
# 263003               2         1              2           2         99
# 263004               2         2              1           2         99
# 263005               2         2              2           2          2
# 263006               2         2              2           2          2
#
#         MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN UCI
# 0             99           M̩xico          97  97
# 1             99           M̩xico          97   2
# 2             99           M̩xico          97   2
# 3             99           M̩xico          97  97
# 4             99           M̩xico          97  97
# ...          ...               ...         ...  ..
# 263002        99           M̩xico          99  97
# 263003        99           M̩xico          99   2
# 263004        99           M̩xico          99   2
# 263005        99           M̩xico          99   2
# 263006        99           M̩xico          99  97
#
# [263007 rows x 41 columns]

# %%
df.drop(['FECHA_ARCHIVO','ID_REGISTRO','ENTIDAD','FECHA_ACTUALIZACION','EDAD','FECHA_SINTOMAS'],
        axis=1 , inplace= True)

# %%
df
# Out:
#              id  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  ENTIDAD_REGISTRO  \
# 0          9269          25           25          2    NaN                25
# 1         33333          14           14          2    NaN                14
# 2         35483           8            8          1    NaN                 8
# 3          7062           9           15          1    NaN                 9
# 4         23745           9            9          2    NaN                 9
# ...         ...         ...          ...        ...    ...               ...
# 263002  7094887          32           32          1    NaN                32
# 263003  7053721          12           12          1    NaN                12
# 263004  7055429          20           20          1    NaN                20
# 263005  7043768          13           13          1    NaN                13
# 263006  7093277           9            9          1    NaN                 9
#
#        ABR_ENT  ORIGEN  SECTOR  SEXO  ...  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 0           SL       2      12     2  ...         2               2         1
# 1           JC       1       4     1  ...         2               2         1
# 2           CH       1       4     2  ...         2               2         2
# 3           DF       2       4     1  ...         2               2         1
# 4           DF       1       4     1  ...         2               2         2
# ...        ...     ...     ...   ...  ...       ...             ...       ...
# 263002      ZS       2      12     2  ...         2               2         2
# 263003      GR       2       4     1  ...         2               2         1
# 263004      OC       1       4     1  ...         2               2         2
# 263005      HG       2      12     2  ...         2               2         2
# 263006      DF       2      12     1  ...         2               2         2
#
#        RENAL_CRONICA TABAQUISMO  OTRO_CASO  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                  2          2          2        99            M̩xico
# 1                  2          1         99        99            M̩xico
# 2                  2          2         99        99            M̩xico
# 3                  2          2         99        99            M̩xico
# 4                  2          2         99        99            M̩xico
# ...              ...        ...        ...       ...                ...
# 263002             2          2          1        99            M̩xico
# 263003             2          2         99        99            M̩xico
# 263004             1          2         99        99            M̩xico
# 263005             2          2          2        99            M̩xico
# 263006             2          2          2        99            M̩xico
#
#         PAIS_ORIGEN  UCI
# 0                97   97
# 1                97    2
# 2                97    2
# 3                97   97
# 4                97   97
# ...             ...  ...
# 263002           99   97
# 263003           99    2
# 263004           99    2
# 263005           99    2
# 263006           99   97
#
# [263007 rows x 35 columns]
